# %%
import os
os.getcwd()
# Out:
# '/Users/camilomunoz/Downloads/obesity_streamlit_app'

# %%
import os
os.listdir()
# Out:
# ['artifacts',
#  '.DS_Store',
#  'requirements.txt',
#  'train_model.py',
#  'run_local.sh',
#  'Untitled.ipynb',
#  'README.md',
#  '.gitignore',
#  'app.py',
#  '.ipynb_checkpoints',
#  'data']

# %%
import os
os.listdir("data")
# Out:
# ['ObesityDataSet_raw_and_data_sinthetic.csv']

# %%
# !pip install -r requirements.txt

# %%
# !python train_model.py
# Out:
# OK - Artefactos generados:
# - artifacts/model.joblib
# - artifacts/metrics.json
# Accuracy (test): 0.9318

# %%
import os
os.listdir("artifacts")
# Out:
# ['metrics.json', 'model.joblib']

# %%
# !ls -la .streamlit
# Out:
# total 8
# drwxr-xr-x   3 camilomunoz  staff   96 Jan 31 15:10 .
# drwxr-xr-x@ 14 camilomunoz  staff  448 Jan 31 15:09 ..
# -rw-r--r--@  1 camilomunoz  staff  143 Jan 31 15:03 config.toml

# %%
# !pip install plotly

# %%
# !streamlit run app.py
# Out:
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://192.168.1.84:8501
#
# 2026-01-31 17:10:20.177 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2026-01-31 17:11:01.418 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# ^C
#   Stopping...
